# %% [markdown]
# ## IMSE 586 Homework 2
# ### Due on October 4, 2019 at 11:59 PM

# %% [markdown]
# ### Homework Policies (please read them carefully):
# * Late homework will not be accepted without valid documented excuse. Barring extraordinary circumstances, the documented excuse must be available to the instructor at least two-days prior to the homework due date.
#
#
# * All homework are to be completed on your own. You are allowed to consult with other students in the current class during the conceptualization of a problem. However, all written work, whether in scrap or final form, are to be generated by you working alone.
#
#
# * You are not allowed to discuss the problem set with previous class members, nor anyone else who has significant knowledge of the details of the problem set. You should not compare your written solutions, whether in scrap paper form, or your final work product, to other students.
#
#
# * You are also not allowed to possess, look at, use, or in any way derive advantage from the existence of solutions prepared in prior semesters, whether these solutions were former students' work product or copies of solutions that had been made available by the instructors.

# %% [markdown]
# **Honor Code** applies. Please sign your pledge that “**I have not received or given any unauthorized aid on this assignment.**”
#
# **Sign your full name here**:
# ***

# %% [markdown]
# ### Please enter the following information.
#
# **Your full name:**
#
# **Your UMICH email:**
#
# **List with whom you have discussed the homework problems. Leave it blank if you did not discuss the problem with anyone.**
# * Problem 1: I have discussed it with
#
#
# * Problem 2: I have discussed it with

# %% [markdown]
# ### Submission requirements:
#
# * Use this Jupyter notebook file as the starting point, and include all your code and answers in it.
#
#
# * Type in your answers to the questions explicitly and clearly in markdown cells. So I dont' have to search for the numbers in the output.
#
#
# * You will submit a <a href=https://en.wikipedia.org/wiki/Zip_(file_format)>.zip</a> file called "IMSE586_HWX_yourUniqueName.zip", where X is the number of the current homework. So, if I were to submit for homework 2, it would be called "IMSE586_HW2_fredfeng.zip".
#
#
# * When I extract your compressed file, the result should be a directory called "IMSE586_HWX_yourUniqueName", containing, at a minimum, a jupyter notebook file called "IMSE586_HWX_yourUniqueName.ipynb" and all the data files needed to run your code. In short, I should be able to extract your archived file and run your notebook file on my own machine by opening it in Jupyter and clicking, for example, Cells->Run all. Importantly, please ensure that none of the code in your submitted notebook file results in errors.

# %% [markdown]
# ### General suggestions
#
# * **Start early!** If you run into software or coding issues, it may takes time to solve. It is the best to find these problems early so we have time to help you.
#
#
# * **Back up your work!** I would recommend to do your work in a <a href=https://its.umich.edu/communication/collaboration/box>U-M Box</a> or Dropbox folder.
#
#
# * **Make your code easier to read!**
#     - Don't write all your code in one cell. Seperate different parts of your code in different cells. Check our lecture examples.
#     - Use markdown cells to explain and document your work. Use comments in code cells to explain your code.
#     - Follow naming conventions (e.g., `import pandas as pd`).
#     - Use meaningful variable names.
#
# ***

# %% [markdown]
# ### Problem 1 - Starbucks Nutrition Data (12 pts)
#
# Download the Starbucks nutrition data from Canvas that is along with this notebook (data source: https://www.kaggle.com/starbucks/starbucks-menu#starbucks_drinkMenu_expanded.csv)
#
# Read the data into a pandas dataframe. First, check the data by looking at the first and last few rows, the data types of the columns, and check the data types of the columns and rename the columns to have no spaces (if needed). Then, answer the following questions:
#
#
# 1. What are the mean and median values of calories from all items?
#
#
# 2. How many items have no less than 250 calories?
#
#
# 3. Which item(s) have the highest percentage of calories from protein? (Hint: protein has 4 calories per gram)
#
#
# 4. Create a scatter plot of the calories against sugars from all the items. The plot should include all important elements (e.g., x & y labels, title) and be easy to read (e.g., using larger fonts if needed).

# %%
import pandas as pd

# %% [markdown]
# ### Problem 2 - Marathon Time data (12 pts)
#
# Download the data from the following link:
# https://github.com/jakevdp/marathon-data
#
# The split column records the time in HH:MM:SS when a runner reached the half way point of the race.
#
# Read the data into a pandas dataframe. First, check the data by looking at the first and last few rows, the data types of the columns, and check the data types of the columns and rename the columns to have no spaces (if needed). Then, answer the following questions:
#
#
# 1. Create two new columns called `split_sec` and `final_sec`, which are the split and final time in seconds. For example, 04:24:24 would be $4\times3600+24\times60+24=15864$ seconds. (Hint: Check the lecture example on how we converted a string to a number using the `split` function. Python funciton `int()` converts a string to an integer.)
#
#
# 2. How many men (M) and women (W) were in the data? How many men and women in age group 18-34, inclusive, were in the data? (hint: to filter the data by a lower and uper bound, you can set two criteria, or better yet, use pandas function `.between` <a href=https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.between.html>link</a>)
#
#
# 3. The <a href=https://www.baa.org/races/boston-marathon/enter/qualify>qualifying time</a> of the prestigious Boston Marathon is 3:00:00 for men and 3:30:00 for women in the age group of 18-34, inclusive. What is the percentage of men in this age group who qualified for Boston? Round your answer to 3 decimal places (e.g., 0.456). You may use the Python `round` function. <a href = https://docs.python.org/3/library/functions.html#round>link</a>.
#
#
# 4. In competitive marathon, it's generally better to have a <a href=https://en.wikipedia.org/wiki/Negative_split>negative split</a> (although very hard to do), which is to run the second half of the race faster than the first half. What's the percentage of the runners in our data that had a negative split? How about for those who finished under 2.5 hours (i.e., more elite runners)? Round your answers to 3 decimal places.

# %%
# Write your code here. You should add more cells.
